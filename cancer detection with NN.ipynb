# %%
import pandas as pd
import numpy as np

# %%
# Load data
data = pd.read_csv('cancer_data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(['id', 'Unnamed: 32'], axis=1)

# %%
# Convert diagnosis to binary
data['diagnosis'] = data['diagnosis'].map({'M':1, 'B':0})

# %%
# normalize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data.drop('diagnosis', axis=1))
scaled_features = scaler.transform(data.drop('diagnosis', axis=1))

df_feat = pd.DataFrame(scaled_features, columns=data.columns[1:])
df_feat.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                2.255747  ...      1.886690      -1.359293         2.303601
# 1               -0.868652  ...      1.805927      -0.369203         1.535126
# 2               -0.398008  ...      1.511870      -0.023974         1.347475
# 3                4.910919  ...     -0.281464       0.133984        -0.249939
# 4               -0.562450  ...      1.298575      -1.466770         1.338539
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    2.001237          1.307686           2.616665         2.109526
# 1    1.890489         -0.375612          -0.430444        -0.146749
# 2    1.456285          0.527407           1.082932         0.854974
# 3   -0.550021          3.394275           3.893397         1.989588
# 4    1.220724          0.220556          -0.313395         0.613179
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.750622                 1.937015
# 1              1.087084       -0.243890                 0.281190
# 2              1.955000        1.152255                 0.201391
# 3              2.175786        6.046041                 4.935010
# 4              0.729259       -0.868353                -0.397100
#
# [5 rows x 30 columns]

# %%
# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X = df_feat
y = data['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# create a neyral network model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()

model.add(layers.Dense(64, activation='relu', input_shape=(30,)))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# train the model
model.fit(X_train, y_train, epochs=10, batch_size=1, verbose=1)

# evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 455/455 [==============================] - 3s 4ms/step - loss: 0.1623 - accuracy: 0.9495
# Epoch 2/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0727 - accuracy: 0.9846
# Epoch 3/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0535 - accuracy: 0.9846
# Epoch 4/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0445 - accuracy: 0.9890
# Epoch 5/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0340 - accuracy: 0.9912
# Epoch 6/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0266 - accuracy: 0.9890
# Epoch 7/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0237 - accuracy: 0.9912
# Epoch 8/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0235 - accuracy: 0.9890
# Epoch 9/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0350 - accuracy: 0.9824
# Epoch 10/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0120 - accuracy: 0.9978
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9649
# Test accuracy: 0.9649122953414917
